# %% [markdown]
# <a href="https://colab.research.google.com/github/yokesh0419/FUTURE_DS_01/blob/main/FUTURE_DS_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob

# %%
df = pd.read_csv('/content/student_feedback.csv',encoding='latin1')
df.head()
# Out:
#    SN  Total Feedback Given  ...              Course Name            Basic Course
# 0   1                     1  ...  FY B.VOC FOOD TECHNOLOGY  B.VOC FOOD TECHNOLOGY
# 1   2                     1  ...  FY B.VOC FOOD TECHNOLOGY  B.VOC FOOD TECHNOLOGY
# 2   3                     1  ...  FY B.VOC FOOD TECHNOLOGY  B.VOC FOOD TECHNOLOGY
# 3   4                     1  ...  FY B.VOC FOOD TECHNOLOGY  B.VOC FOOD TECHNOLOGY
# 4   5                     1  ...  FY B.VOC FOOD TECHNOLOGY  B.VOC FOOD TECHNOLOGY
#
# [5 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# SN                      0
# Total Feedback Given    0
# Total Configured        0
# Questions               0
# Weightage 1             0
# Weightage 2             0
# Weightage 3             0
# Weightage 4             0
# Weightage 5             0
# Average/ Percentage     0
# Course Name             0
# Basic Course            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# SN                       int64
# Total Feedback Given     int64
# Total Configured         int64
# Questions               object
# Weightage 1              int64
# Weightage 2              int64
# Weightage 3              int64
# Weightage 4              int64
# Weightage 5              int64
# Average/ Percentage     object
# Course Name             object
# Basic Course            object
# dtype: object

# %%
#rating columns
rating_columns = ['Total Feedback Given',
                  'Total Configured',
                  'Weightage 1',
                  'Weightage 2',
                  'Weightage 3',
                  'Weightage 4',
                  'Weightage 5']

# Average rating
avg_ratings = df[rating_columns].mean().round(1)

print(avg_ratings)
# Out:
# Total Feedback Given    14.3
# Total Configured        92.5
# Weightage 1              0.5
# Weightage 2              1.2
# Weightage 3              2.5
# Weightage 4              5.1
# Weightage 5              5.0
# dtype: float64

# %%
# set plot size
plt.figure(figsize=(10, 6))

#plot bar chart
sns.barplot(x=avg_ratings.values, y=avg_ratings.index,palette="viridis")

#Title & lables
plt.title('Average Feedback Ratings for Each parameter')
plt.xlabel('Average Rating')
plt.ylabel('Feedback Parameters')

#show plot
plt.show()
# Out:
# /tmp/ipython-input-17-1899035706.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_ratings.values, y=avg_ratings.index,palette="viridis")

# %%
corr = df[rating_columns].corr()


plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Correlation Heatmap of Feedback Parameter')
plt.show()

# %%
rating_counts = df['Total Configured'].value_counts().sort_index()


plt.figure(figsize=(7, 7))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(rating_counts)))
plt.title('Distribution of Total Configured Ratings')
plt.show()
